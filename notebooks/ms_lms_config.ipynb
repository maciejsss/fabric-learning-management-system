# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, FloatType, DoubleType, DateType
from pyspark.sql.functions import col, lit, current_timestamp, concat, to_timestamp, count, sum, avg, max, min, countDistinct, desc, rank, when, row_number, to_date, round
from pyspark.sql.window import Window
from delta.tables import DeltaTable
# Out:
# StatementMeta(, 43816f38-d5e7-499a-bca7-8620661b6ac7, 3, Finished, Available, Finished)

# %%
account_name = 'lmsstorageprodpl'
raw_container = 'raw'
raw_relative_path = 'raw'
landing_relative_path = 'landing'
